# %%
import model
from mpltools import style
style.use("ggplot")

# %% [markdown]
# Checking the new `k` mutatio rate function

# %%
w = array([0.9**i for i in range(50)])

# %%
M1 = model.mutation_rates_matrix_simk(0.1, 1, 10, w)
M10 = model.mutation_rates_matrix_simk(0.1, 3, 10, w)
M01 = model.mutation_rates_matrix_simk(0.1, 1/3., 10, w)

# %%
plot(w,M1,label='1')
plot(w,M10,label='10')
plot(w,M01,label='0.1')
legend()
xlim((0,1))
ylim((0,1.1))
title("Compare to Fig. 1 in Argrawal 2002");
