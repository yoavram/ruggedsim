# %%
import model
from mpltools import style
style.use("ggplot")

# %% [markdown]
# Checking the new `k` mutatio rate function

# %%
U = 0.0004
s = 0.05
tau = 50
w = array([(1-s)**i for i in range(100)])

# %%
M1 = model.mutation_rates_matrix_simk(U, 1, tau, w)
M10 = model.mutation_rates_matrix_simk(U, 3, tau, w)
M01 = model.mutation_rates_matrix_simk(U, 1/3., tau, w)

# %%
plot(w,M1,label='1')
plot(w,M10,label='10')
plot(w,M01,label='0.1')
legend(title=M"k",loc=3)
xlim((0,1))
ylim((0,tau*U*1.1))
title("Compare to Fig. 1 in Argrawal 2002")
xlabel("fitness")
ylabel("mutation rate")
axvline(x=1-s);

# %%
M1[1]/M1[0]
# Out:
# 3.449999999999998
